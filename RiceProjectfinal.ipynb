# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/content/ImajeJ - rice project1.csv")

# %%
dataset.head()
# Out:
#    Unnamed: 0   AREA  PERIMETER   ANGLE    FERET  FERETX  FERETY   FERETZ  \
# 0         1.0  199.0    198.023   0.868  198.023   552.0   660.0    0.868
# 1         2.0   64.0     63.285 -84.560   63.285   654.0   633.0   95.440
# 2         3.0  143.0    142.302 -18.435  142.302   588.0   630.0  161.565
# 3         4.0  143.0    141.510  21.125  141.510   588.0   681.0   21.125
# 4         NaN    NaN        NaN     NaN      NaN     NaN     NaN      NaN
#
#    MINFERET   LENGTH  ...  Area/FeretX  Area/FeretY  Area/FeretZ  \
# 0       0.0  198.023  ...     0.360507     0.301515   229.262673
# 1       0.0   63.285  ...     0.097859     0.101106     0.670578
# 2       0.0  142.302  ...     0.243197     0.226984     0.885093
# 3       0.0  141.510  ...     0.243197     0.209985     6.769231
# 4       NaN      NaN  ...     0.000000     0.000000     0.000000
#
#    Perimeter/FeretX  Perimeter/FeretY  Perimeter/FeretZ  Angle/FeretX  \
# 0          0.358737          0.300035        228.137097      0.001572
# 1          0.096766          0.099976          0.663087     -0.129297
# 2          0.242010          0.225876          0.880772     -0.031352
# 3          0.240663          0.207797          6.698698      0.035927
# 4          0.000000          0.000000          0.000000      0.000000
#
#    Angle/FeretY  Angle/FeretZ   TYPE
# 0      0.001315      1.000000  First
# 1     -0.133586     -0.886002  First
# 2     -0.029262     -0.114103  First
# 3      0.031021      1.000000  First
# 4      0.000000      0.000000  First
#
# [5 rows x 23 columns]

# %%
dataset = dataset.dropna(how='all',axis=1)

# %%
dataset.head()
# Out:
#    Unnamed: 0   AREA  PERIMETER   ANGLE    FERET  FERETX  FERETY   FERETZ  \
# 0         1.0  199.0    198.023   0.868  198.023   552.0   660.0    0.868
# 1         2.0   64.0     63.285 -84.560   63.285   654.0   633.0   95.440
# 2         3.0  143.0    142.302 -18.435  142.302   588.0   630.0  161.565
# 3         4.0  143.0    141.510  21.125  141.510   588.0   681.0   21.125
# 4         NaN    NaN        NaN     NaN      NaN     NaN     NaN      NaN
#
#    MINFERET   LENGTH  ...  Area/FeretX  Area/FeretY  Area/FeretZ  \
# 0       0.0  198.023  ...     0.360507     0.301515   229.262673
# 1       0.0   63.285  ...     0.097859     0.101106     0.670578
# 2       0.0  142.302  ...     0.243197     0.226984     0.885093
# 3       0.0  141.510  ...     0.243197     0.209985     6.769231
# 4       NaN      NaN  ...     0.000000     0.000000     0.000000
#
#    Perimeter/FeretX  Perimeter/FeretY  Perimeter/FeretZ  Angle/FeretX  \
# 0          0.358737          0.300035        228.137097      0.001572
# 1          0.096766          0.099976          0.663087     -0.129297
# 2          0.242010          0.225876          0.880772     -0.031352
# 3          0.240663          0.207797          6.698698      0.035927
# 4          0.000000          0.000000          0.000000      0.000000
#
#    Angle/FeretY  Angle/FeretZ   TYPE
# 0      0.001315      1.000000  First
# 1     -0.133586     -0.886002  First
# 2     -0.029262     -0.114103  First
# 3      0.031021      1.000000  First
# 4      0.000000      0.000000  First
#
# [5 rows x 23 columns]

# %%
dataset = dataset.dropna()

# %%
dataset.head()
# Out:
#    Unnamed: 0   AREA  PERIMETER   ANGLE    FERET  FERETX  FERETY   FERETZ  \
# 0         1.0  199.0    198.023   0.868  198.023   552.0   660.0    0.868
# 1         2.0   64.0     63.285 -84.560   63.285   654.0   633.0   95.440
# 2         3.0  143.0    142.302 -18.435  142.302   588.0   630.0  161.565
# 3         4.0  143.0    141.510  21.125  141.510   588.0   681.0   21.125
# 5         1.0  125.0    123.584  -5.572  123.584   486.0   558.0  174.428
#
#    MINFERET   LENGTH  ...  Area/FeretX  Area/FeretY  Area/FeretZ  \
# 0       0.0  198.023  ...     0.360507     0.301515   229.262673
# 1       0.0   63.285  ...     0.097859     0.101106     0.670578
# 2       0.0  142.302  ...     0.243197     0.226984     0.885093
# 3       0.0  141.510  ...     0.243197     0.209985     6.769231
# 5       0.0  123.584  ...     0.257202     0.224014     0.716628
#
#    Perimeter/FeretX  Perimeter/FeretY  Perimeter/FeretZ  Angle/FeretX  \
# 0          0.358737          0.300035        228.137097      0.001572
# 1          0.096766          0.099976          0.663087     -0.129297
# 2          0.242010          0.225876          0.880772     -0.031352
# 3          0.240663          0.207797          6.698698      0.035927
# 5          0.254288          0.221477          0.708510     -0.011465
#
#    Angle/FeretY  Angle/FeretZ   TYPE
# 0      0.001315      1.000000  First
# 1     -0.133586     -0.886002  First
# 2     -0.029262     -0.114103  First
# 3      0.031021      1.000000  First
# 5     -0.009986     -0.031944  First
#
# [5 rows x 23 columns]

# %%
dataset = dataset.drop(columns = 'Unnamed: 0')

# %%
dataset.head()
# Out:
#     AREA  PERIMETER   ANGLE    FERET  FERETX  FERETY   FERETZ  MINFERET  \
# 0  199.0    198.023   0.868  198.023   552.0   660.0    0.868       0.0
# 1   64.0     63.285 -84.560   63.285   654.0   633.0   95.440       0.0
# 2  143.0    142.302 -18.435  142.302   588.0   630.0  161.565       0.0
# 3  143.0    141.510  21.125  141.510   588.0   681.0   21.125       0.0
# 5  125.0    123.584  -5.572  123.584   486.0   558.0  174.428       0.0
#
#     LENGTH  Area/Perimeter  ...  Area/FeretX  Area/FeretY  Area/FeretZ  \
# 0  198.023        1.004934  ...     0.360507     0.301515   229.262673
# 1   63.285        1.011298  ...     0.097859     0.101106     0.670578
# 2  142.302        1.004905  ...     0.243197     0.226984     0.885093
# 3  141.510        1.010529  ...     0.243197     0.209985     6.769231
# 5  123.584        1.011458  ...     0.257202     0.224014     0.716628
#
#    Perimeter/FeretX  Perimeter/FeretY  Perimeter/FeretZ  Angle/FeretX  \
# 0          0.358737          0.300035        228.137097      0.001572
# 1          0.096766          0.099976          0.663087     -0.129297
# 2          0.242010          0.225876          0.880772     -0.031352
# 3          0.240663          0.207797          6.698698      0.035927
# 5          0.254288          0.221477          0.708510     -0.011465
#
#    Angle/FeretY  Angle/FeretZ   TYPE
# 0      0.001315      1.000000  First
# 1     -0.133586     -0.886002  First
# 2     -0.029262     -0.114103  First
# 3      0.031021      1.000000  First
# 5     -0.009986     -0.031944  First
#
# [5 rows x 22 columns]

# %%
#identifying all the numeric columns
numeric = dataset._get_numeric_data()
TYPE = dataset['TYPE']
print(numeric.head())
print("Numeric column: ",end =" ")
print(numeric.columns)
print(len(numeric.columns))

numeric.describe()
# Out:
#     AREA  PERIMETER   ANGLE    FERET  FERETX  FERETY   FERETZ  MINFERET  \
# 0  199.0    198.023   0.868  198.023   552.0   660.0    0.868       0.0
# 1   64.0     63.285 -84.560   63.285   654.0   633.0   95.440       0.0
# 2  143.0    142.302 -18.435  142.302   588.0   630.0  161.565       0.0
# 3  143.0    141.510  21.125  141.510   588.0   681.0   21.125       0.0
# 5  125.0    123.584  -5.572  123.584   486.0   558.0  174.428       0.0
#
#     LENGTH  Area/Perimeter  ...  Area/Angle  Area/FeretX  Area/FeretY  \
# 0  198.023        1.004934  ...  229.262673     0.360507     0.301515
# 1   63.285        1.011298  ...   -0.756859     0.097859     0.101106
# 2  142.302        1.004905  ...   -7.756984     0.243197     0.226984
# 3  141.510        1.010529  ...    6.769231     0.243197     0.209985
# 5  123.584        1.011458  ...  -22.433597     0.257202     0.224014
#
#    Area/FeretZ  Perimeter/FeretX  Perimeter/FeretY  Perimeter/FeretZ  \
# 0   229.262673          0.358737          0.300035        228.137097
# 1     0.670578          0.096766          0.099976          0.663087
# 2     0.885093          0.242010          0.225876          0.880772
# 3     6.769231          0.240663          0.207797          6.698698
# 5     0.716628          0.254288          0.221477          0.708510
#
#    Angle/FeretX  Angle/FeretY  Angle/FeretZ
# 0      0.001572      0.001315      1.000000
# 1     -0.129297     -0.133586     -0.886002
# 2     -0.031352     -0.029262     -0.114103
# 3      0.035927      0.031021      1.000000
# 5     -0.011465     -0.009986     -0.031944
#
# [5 rows x 21 columns]
# Numeric column:  Index(['AREA', 'PERIMETER', 'ANGLE', 'FERET', 'FERETX', 'FERETY', 'FERETZ',
#        'MINFERET', 'LENGTH', 'Area/Perimeter', 'Perimeter/Angle', 'Area/Angle',
#        'Area/FeretX', 'Area/FeretY', 'Area/FeretZ', 'Perimeter/FeretX',
#        'Perimeter/FeretY', 'Perimeter/FeretZ', 'Angle/FeretX', 'Angle/FeretY',
#        'Angle/FeretZ'],
#       dtype='object')
# 21
#                 AREA    PERIMETER       ANGLE       FERET      FERETX  \
# count     726.000000   726.000000  726.000000  726.000000  726.000000
# mean      356.661157   117.343781    7.017894   54.427674  373.178139
# std      7775.591017   101.879772  101.447307   51.198092  237.960242
# min         1.000000    14.560000 -178.831000 -133.264000  -17.447000
# 25%        37.000000    46.885000  -80.538000   24.187000   95.906000
# 50%        70.000000    92.197000   -2.385500   57.704500  451.500000
# 75%        94.000000   219.635000   78.497250   90.796000  585.000000
# max    209572.000000  1834.000000  254.187000  649.419000  735.000000
#
#            FERETY      FERETZ    MINFERET      LENGTH  Area/Perimeter  ...  \
# count  726.000000  726.000000  726.000000  726.000000      726.000000  ...
# mean   506.909708  260.774322   38.330579   65.544744        9.016790  ...
# std    140.418558  258.151945  141.407841   35.576535       30.044875  ...
# min      0.000000    0.000000    0.000000    0.000000        0.124828  ...
# 25%    464.000000   71.565000    0.000000   36.000000        0.532862  ...
# 50%    528.000000  153.435000    0.000000   68.411000        1.012335  ...
# 75%    585.000000  471.750000    0.000000   93.181000        1.025641  ...
# max    849.000000  885.000000  687.000000  198.023000      150.213000  ...
#
#        Area/Angle  Area/FeretX  Area/FeretY  Area/FeretZ  Perimeter/FeretX  \
# count  726.000000   726.000000   726.000000   726.000000        726.000000
# mean     0.293023     0.362593     0.129994     4.943915          0.551329
# std     13.655570     0.422373     0.089707    57.517963          9.968380
# min    -76.310551    -1.169591     0.000000     0.000000       -157.894737
# 25%     -0.521575     0.075378     0.068177     0.149745          0.077158
# 50%     -0.197179     0.152032     0.131940     0.344444          0.160843
# 75%      1.011182     1.006421     0.181349     0.597852          2.180682
# max    229.262673     2.155689     1.674419  1516.626503         49.459548
#
#        Perimeter/FeretY  Perimeter/FeretZ  Angle/FeretX  Angle/FeretY  \
# count        726.000000        726.000000    726.000000    726.000000
# mean           0.273602          2.924291     -0.545270      0.125963
# std            0.253541         12.230469     19.405766      0.568453
# min            0.000000          0.000000   -295.036257     -0.532387
# 25%            0.091724          0.317692     -0.149005     -0.137672
# 50%            0.169453          0.409403     -0.011175     -0.003871
# 75%            0.426334          0.619368      1.000000      0.145720
# max            1.012832        228.137097     91.927366      4.032567
#
#        Angle/FeretZ
# count    726.000000
# mean      -0.977193
# std        6.711297
# min     -152.977759
# 25%       -0.809736
# 50%       -0.013434
# 75%        0.175543
# max        1.000000
#
# [8 rows x 21 columns]

# %%
#creating histogram for better analysis
num_hist = numeric.hist(layout=(3,7),figsize = (20,10))
plt.show()

# %%
#features of each type
grouped_type = dataset.groupby('TYPE')

for col in numeric.columns:
  fig,ax = plt.subplots()

  for i,d in grouped_type:
    d[col].hist(alpha=0.4, ax=ax, label=i, figsize=(10,4))
    ax.set_title(col)

  ax.legend()
  plt.show()

# %%
grouped_type.mean()
# Out:
#                 AREA   PERIMETER       ANGLE       FERET      FERETX  \
# TYPE
# Fifth      82.859375   69.104047  -30.437828   66.953063  470.250000
# First    1121.560000   81.758507  -56.430180   75.939860  583.790000
# Fourth     50.517857   49.582929  -55.471009   49.582929  586.991071
# Seventh     1.000000  118.320000  242.961040  117.388960    3.253080
# Sixth      86.710000  233.853140   85.758375   12.207390   85.758375
# Third      62.710000   61.773090  -47.579260   61.773090  410.160000
#
#              FERETY      FERETZ      MINFERET        LENGTH  Area/Perimeter  \
# TYPE
# Fifth    620.953125   79.182656  1.406250e-01  6.507280e+01        1.067572
# First    513.715000   88.260735  2.165000e+00  7.269276e+01        1.584034
# Fourth   515.339286   90.778991  2.458750e-16  4.958293e+01        1.024531
# Seventh  117.388960  413.540000  5.477200e+02  3.108400e-16      117.388960
# Sixth    527.770000  632.380000  5.419600e-16  8.575838e+01        0.372213
# Third    563.910000   92.820740  2.131200e-16  6.177309e+01        1.024200
#
#          ...  Area/Angle  Area/FeretX  Area/FeretY  Area/FeretZ  \
# TYPE     ...
# Fifth    ...   -1.996539     0.179151     0.133825     3.525081
# First    ...   -0.738795     0.127994     0.146287    12.402312
# Fourth   ...   -0.091484     0.088015     0.100983     2.365298
# Seventh  ...    0.004126    -0.047543     0.008680     0.002460
# Sixth    ...    1.012337     1.012337     0.167248     0.142302
# Third    ...    2.958446     0.162298     0.113594     5.897179
#
#          Perimeter/FeretX  Perimeter/FeretY  Perimeter/FeretZ  Angle/FeretX
perimeter/FeretY  Perimeter/FeretZ  Angle/FeretX  Angle/FeretY  \
# TYPE
# Fifth            0.400000         25.248713      0.206897      0.144231
# First            0.300035        228.137097      0.315789      0.387097
# Fourth           0.231996         32.329328      0.043185      0.039379
# Seventh          1.012832          0.407051     91.927366      4.032567
# Sixth            0.656253          0.704476      1.000000      0.309480
# Third            0.312607         75.672860      0.076923      0.095541
#
#          Angle/FeretZ
# TYPE
# Fifth        1.000000
# First        1.000000
# Fourth       1.000000
# Seventh      0.822317
# Sixth        0.299444
# Third        1.000000
#
# [6 rows x 21 columns]

# %%
org = dataset['TYPE']

# %%
fig = plt.figure(figsize = (20,10))
plt.bar(height=dataset['TYPE'].value_counts().values,x=dataset['TYPE'].value_counts().index)
plt.show()

# %%
#packages for correlation analysis
import seaborn as sns
import joblib
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler
from imblearn.over_sampling import SMOTE

# %%
dataset['TYPE'] = LabelEncoder().fit_transform(dataset['TYPE'])
corr = dataset.corr()
sns.heatmap(data=corr)
# Out:
# <Axes: >

# %%
#Define Features(Indedpendent Variables)
x = dataset.iloc[:,1:-1].values

# %%
#Define target
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_rf = RandomForestClassifier(random_state = 0)
classifier_rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred = classifier_rf.predict(x_test)
y_prob = classifier_rf.predict_proba(x_test)
#Applying various metrics to check the validity of the model
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score,confusion_matrix, roc_auc_score
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average = 'micro')
prec = precision_score(y_test, y_pred, average='micro')
rec = recall_score(y_test, y_pred,average='micro')
roc_auc = roc_auc_score(y_test,y_prob,multi_class='ovr',average = 'micro')

# %%
results = pd.DataFrame([["Random Forest", acc, f1, prec, rec,roc_auc]],
                       columns = ['Model','Accuracy','F1 Score', 'Precision','Recall','ROC/AUC'])
results
# Out:
#            Model  Accuracy  F1 Score  Precision    Recall   ROC/AUC
# 0  Random Forest  0.863014  0.863014   0.863014  0.863014  0.982389

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot = True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier_rf, X= x_train, y=y_train, cv = 10)
print("Accuracy is {:.2f}%".format(accuracies.mean()*100))
print("Standard Devation is {:.2f}%".format(accuracies.std()*100))
# Out:
# Accuracy is 83.28%
# Standard Devation is 5.06%

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
classifier_dt = DecisionTreeClassifier(max_depth = 2).fit(x_train, y_train)

# %%
y_pred = classifier_dt.predict(x_test)
y_prob = classifier_dt.predict_proba(x_test)
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score,confusion_matrix,roc_auc_score
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average = 'micro')
prec = precision_score(y_test, y_pred, average='micro')
rec = recall_score(y_test, y_pred,average='micro')
roc_auc = roc_auc_score(y_test,y_prob,multi_class='ovr',average = 'micro')

# %%
res = pd.DataFrame([["Decision Tree", acc, f1, prec, rec,roc_auc]],
                       columns = ['Model','Accuracy','F1 Score', 'Precision','Recall', 'ROC/AUC'])
results = results.append(res,ignore_index = True)
results
# Out:
# <ipython-input-33-91a75ea689e3>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(res,ignore_index = True)
#            Model  Accuracy  F1 Score  Precision    Recall   ROC/AUC
# 0  Random Forest  0.863014  0.863014   0.863014  0.863014  0.982389
# 1  Decision Tree  0.691781  0.691781   0.691781  0.691781  0.940270

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot = True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier_dt, X= x_train, y=y_train, cv = 10)
print("Accuracy is {:.2f}%".format(accuracies.mean()*100))
print("Standard Devation is {:.2f}%".format(accuracies.std()*100))
# Out:
# Accuracy is 62.76%
# Standard Devation is 2.07%

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
classifier_svm = SVC(probability = True,kernel = 'linear', C = 1).fit(x_train, y_train)
y_pred = classifier_svm.predict(x_test)
y_prob = classifier_svm.predict_proba(x_test)

# %%
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average = 'micro')
prec = precision_score(y_test, y_pred, average='micro')
rec = recall_score(y_test, y_pred,average='micro')
roc_auc = roc_auc_score(y_test,y_prob,multi_class='ovr',average = 'micro')

# %%
res1 = pd.DataFrame([["SVM", acc, f1, prec, rec,roc_auc]],
                       columns = ['Model','Accuracy','F1 Score', 'Precision','Recall','ROC/AUC'])
results = results.append(res1,ignore_index = True)
results
# Out:
# <ipython-input-38-ce026aad43b8>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(res1,ignore_index = True)
#            Model  Accuracy  F1 Score  Precision    Recall   ROC/AUC
# 0  Random Forest  0.863014  0.863014   0.863014  0.863014  0.982389
# 1  Decision Tree  0.691781  0.691781   0.691781  0.691781  0.940270
# 2            SVM  0.739726  0.739726   0.739726  0.739726  0.968822

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot = True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier_svm, X= x_train, y=y_train, cv = 10)
print("Accuracy is {:.2f}%".format(accuracies.mean()*100))
print("Standard Devation is {:.2f}%".format(accuracies.std()*100))
# Out:
# Accuracy is 74.31%
# Standard Devation is 4.90%

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn = KNeighborsClassifier(n_neighbors = 7).fit(x_train, y_train)
y_pred = classifier_knn.predict(x_test)
y_prob = classifier_knn.predict_proba(x_test)

# %%
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average = 'micro')
prec = precision_score(y_test, y_pred, average='micro')
rec = recall_score(y_test, y_pred,average='micro')
roc_auc = roc_auc_score(y_test,y_prob,multi_class='ovr',average = 'micro')

# %%
res2 = pd.DataFrame([["KNN", acc, f1, prec, rec,roc_auc]],
                       columns = ['Model','Accuracy','F1 Score', 'Precision','Recall', 'ROC/AUC'])
results = results.append(res2,ignore_index = True)
results
# Out:
# <ipython-input-43-7426343fffcf>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(res2,ignore_index = True)
#            Model  Accuracy  F1 Score  Precision    Recall   ROC/AUC
# 0  Random Forest  0.863014  0.863014   0.863014  0.863014  0.982389
# 1  Decision Tree  0.691781  0.691781   0.691781  0.691781  0.940270
# 2            SVM  0.739726  0.739726   0.739726  0.739726  0.968822
# 3            KNN  0.842466  0.842466   0.842466  0.842466  0.964984

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot = True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier_knn, X= x_train, y=y_train, cv = 10)
print("Accuracy is {:.2f}%".format(accuracies.mean()*100))
print("Standard Devation is {:.2f}%".format(accuracies.std()*100))
# Out:
# Accuracy is 79.66%
# Standard Devation is 3.68%

# %% [markdown]
# # NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB
classifier_gnb = GaussianNB().fit(x_train, y_train)
y_pred = classifier_gnb.predict(x_test)
y_prob = classifier_gnb.predict_proba(x_test)

# %%
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average = 'micro')
prec = precision_score(y_test, y_pred, average='micro')
rec = recall_score(y_test, y_pred,average='micro')
roc_auc = roc_auc_score(y_test,y_prob,multi_class='ovr',average = 'micro')

# %%
res3 = pd.DataFrame([["Naive Bayes", acc, f1, prec, rec,roc_auc]],
                       columns = ['Model','Accuracy','F1 Score', 'Precision','Recall','ROC/AUC'])
results = results.append(res3,ignore_index = True)
results
# Out:
# <ipython-input-48-ce63302687fc>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(res3,ignore_index = True)
#            Model  Accuracy  F1 Score  Precision    Recall   ROC/AUC
# 0  Random Forest  0.863014  0.863014   0.863014  0.863014  0.982389
# 1  Decision Tree  0.691781  0.691781   0.691781  0.691781  0.940270
# 2            SVM  0.739726  0.739726   0.739726  0.739726  0.968822
# 3            KNN  0.842466  0.842466   0.842466  0.842466  0.964984
# 4    Naive Bayes  0.554795  0.554795   0.554795  0.554795  0.902393

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm,annot = True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier_gnb, X= x_train, y=y_train, cv = 10)
print("Accuracy is {:.2f}%".format(accuracies.mean()*100))
print("Standard Devation is {:.2f}%".format(accuracies.std()*100))
# Out:
# Accuracy is 58.62%
# Standard Devation is 4.15%

# %% [markdown]
# ### MODEL LOADING(RANDOM FOREST)

# %%
import pickle
filename = 'modelrf.sav'
pickle.dump(classifier_rf, open(filename,'wb'))

# %%
load_model = pickle.load(open(filename,'rb'))

# %%
dataset.head()
# Out:
#     AREA  PERIMETER   ANGLE    FERET  FERETX  FERETY   FERETZ  MINFERET  \
# 0  199.0    198.023   0.868  198.023   552.0   660.0    0.868       0.0
# 1   64.0     63.285 -84.560   63.285   654.0   633.0   95.440       0.0
# 2  143.0    142.302 -18.435  142.302   588.0   630.0  161.565       0.0
# 3  143.0    141.510  21.125  141.510   588.0   681.0   21.125       0.0
# 5  125.0    123.584  -5.572  123.584   486.0   558.0  174.428       0.0
#
#     LENGTH  Area/Perimeter  ...  Area/FeretX  Area/FeretY  Area/FeretZ  \
# 0  198.023        1.004934  ...     0.360507     0.301515   229.262673
# 1   63.285        1.011298  ...     0.097859     0.101106     0.670578
# 2  142.302        1.004905  ...     0.243197     0.226984     0.885093
# 3  141.510        1.010529  ...     0.243197     0.209985     6.769231
# 5  123.584        1.011458  ...     0.257202     0.224014     0.716628
#
#    Perimeter/FeretX  Perimeter/FeretY  Perimeter/FeretZ  Angle/FeretX  \
# 0          0.358737          0.300035        228.137097      0.001572
# 1          0.096766          0.099976          0.663087     -0.129297
# 2          0.242010          0.225876          0.880772     -0.031352
# 3          0.240663          0.207797          6.698698      0.035927
# 5          0.254288          0.221477          0.708510     -0.011465
#
#    Angle/FeretY  Angle/FeretZ  TYPE
# 0      0.001315      1.000000     1
# 1     -0.133586     -0.886002     1
# 2     -0.029262     -0.114103     1
# 3      0.031021      1.000000     1
# 5     -0.009986     -0.031944     1
#
# [5 rows x 22 columns]

# %%
sample =np.array([64.0,63.285,-84.560,63.285,654.0,633.0,95.440,0.0,63.280,1.011200,-0.1101,-0.75686,0.097859,0.101105845,0.670578374,0.096766055,0.099976303,0.663086756,-0.129296636,-0.133586098,-0.886])
sample.reshape(1,-1)
#load_model.predict(sample)
# Out:
# array([[ 6.40000000e+01,  6.32850000e+01, -8.45600000e+01,
#          6.32850000e+01,  6.54000000e+02,  6.33000000e+02,
#          9.54400000e+01,  0.00000000e+00,  6.32800000e+01,
#          1.01120000e+00, -1.10100000e-01, -7.56860000e-01,
#          9.78590000e-02,  1.01105845e-01,  6.70578374e-01,
#          9.67660550e-02,  9.99763030e-02,  6.63086756e-01,
#         -1.29296636e-01, -1.33586098e-01, -8.86000000e-01]])

# %%
#Attempting to interact with the model and get a classification from a user data
